# %%
import pandas as pd
import os
import re
import scipy

# %%
data_dir='../../srndna-data/stimuli/psychopy/logs'
subs=[p for p in os.listdir(data_dir) if p.startswith(('1','2'))]

f_list=[]
for sub in subs:
    f_list= f_list+[data_dir+"/%s/"%(sub)+f for f in os.listdir(data_dir+"/%s"%(sub)) if 'ultimatum' in f]

df_list=[]
for f in f_list:
    sub=re.search('logs/(.*)/',f).group(1)
    tmp=pd.read_csv(f)
    if len(tmp[tmp['Partner']=='Partner'])>0:
        x=tmp[tmp['Partner']=='Partner'].index[-1]
        tmp=pd.read_csv(f,skiprows=x)

    tmp['sub']=sub
    df_list.append(tmp)
df=pd.concat(df_list)
df.reset_index(inplace=True)
df=df[['sub','Partner','Offer','resp']]
df=df.rename(columns={'sub':"subjID",
                     "Offer":"offer",
                     "resp":"accept"})
df['accept']=pd.to_numeric(df['accept'])-2
df=df[df['accept']<=900]
df.dropna(inplace=True)
display(df.head())
for column in df.columns:
    print ("Unique values for  "+column+":",df[column].unique())
# Out:
#   subjID  Partner  offer  accept
# 1    217      3.0    2.0     0.0
# 2    217      3.0    2.0     0.0
# 3    217      3.0    3.0     0.0
# 4    217      3.0    2.0     0.0
# 5    217      3.0    8.0     1.0
# Unique values for  subjID: ['217' '129' '231' '149' '234' '256' '255' '152' '239' '228' '137' '130'
#  '103' '153' '204' '155' '150' '247' '221' '258' '159' '124' '209' '118'
#  '105' '158' '238' '227' '220' '215' '156' '236' '114' '136' '249' '253'
#  '115' '106' '211' '113' '207' '101' '230' '250' '212' '216' '125' '126'
#  '134' '257' '138' '154' '240' '110' '208' '235' '133' '254' '104' '120'
#  '224' '225' '112' '223' '241' '259' '107' '242' '252' '151' '128' '246'
#  '102' '237' '147' '210' '157' '218' '243' '111' '206' '251' '116' '131'
#  '142' '121' '205' '132' '233' '226' '140' '117' '135' '127' '108' '222'
#  '122' '141' '145' '245' '109' '213']
# Unique values for  Partner: [3. 2. 1.]
# Unique values for  offer: [ 2.  3.  8.  6.  1.  9. 10.  4.  7.  5.]
# Unique values for  accept: [0. 1.]

# %%
df1=df[df['Partner']==1].copy()
df2=df[df['Partner']==2].copy()
df3=df[df['Partner']==3].copy()
df4=[]
display(df1)
for tmp in [df1,df2,df3]:
    display()
    tmp['subjID']=tmp['subjID']+'_'+tmp['Partner'].astype(int).astype(str)
    df4.append(tmp)
    
df4=pd.concat(df4)
df4['subjID'].unique()
# Out:
#       subjID  Partner  offer  accept
# 24       217      1.0    4.0     0.0
# 25       217      1.0    6.0     0.0
# 26       217      1.0    7.0     1.0
# 27       217      1.0    8.0     1.0
# 28       217      1.0    7.0     1.0
# ...      ...      ...    ...     ...
# 14952    213      1.0    3.0     0.0
# 14953    213      1.0    2.0     0.0
# 14954    213      1.0    4.0     0.0
# 14955    213      1.0    2.0     0.0
# 14956    213      1.0    9.0     1.0
#
# [4769 rows x 4 columns]
# array(['217_1', '129_1', '231_1', '149_1', '234_1', '256_1', '255_1',
#        '152_1', '239_1', '228_1', '137_1', '130_1', '103_1', '153_1',
#        '204_1', '155_1', '150_1', '247_1', '221_1', '258_1', '159_1',
#        '124_1', '209_1', '118_1', '105_1', '158_1', '238_1', '227_1',
#        '220_1', '215_1', '156_1', '236_1', '114_1', '136_1', '249_1',
#        '253_1', '115_1', '106_1', '211_1', '113_1', '207_1', '101_1',
#        '230_1', '250_1', '212_1', '216_1', '125_1', '126_1', '134_1',
#        '257_1', '138_1', '154_1', '240_1', '110_1', '208_1', '235_1',
#        '133_1', '254_1', '104_1', '120_1', '224_1', '225_1', '112_1',
#        '223_1', '241_1', '259_1', '107_1', '242_1', '252_1', '151_1',
#        '128_1', '246_1', '102_1', '237_1', '147_1', '210_1', '157_1',
#        '218_1', '243_1', '111_1', '206_1', '251_1', '116_1', '131_1',
#        '142_1', '121_1', '205_1', '132_1', '233_1', '226_1', '140_1',
#        '117_1', '135_1', '127_1', '108_1', '222_1', '122_1', '141_1',
#        '145_1', '245_1', '109_1', '213_1', '217_2', '129_2', '231_2',
#        '149_2', '234_2', '256_2', '255_2', '152_2', '239_2', '228_2',
#        '137_2', '130_2', '103_2', '153_2', '204_2', '155_2', '150_2',
#        '247_2', '221_2', '258_2', '159_2', '124_2', '209_2', '118_2',
#        '105_2', '158_2', '238_2', '227_2', '220_2', '215_2', '156_2',
#        '236_2', '114_2', '136_2', '249_2', '253_2', '115_2', '106_2',
#        '211_2', '113_2', '207_2', '101_2', '230_2', '250_2', '212_2',
#        '216_2', '125_2', '126_2', '134_2', '257_2', '138_2', '154_2',
#        '240_2', '110_2', '208_2', '235_2', '133_2', '254_2', '104_2',
#        '120_2', '224_2', '225_2', '112_2', '223_2', '241_2', '259_2',
#        '107_2', '242_2', '252_2', '151_2', '128_2', '246_2', '102_2',
#        '237_2', '147_2', '210_2', '157_2', '218_2', '243_2', '111_2',
#        '206_2', '251_2', '116_2', '131_2', '142_2', '121_2', '205_2',
#        '132_2', '233_2', '226_2', '140_2', '117_2', '135_2', '127_2',
#        '108_2', '222_2', '122_2', '141_2', '145_2', '245_2', '109_2',
#        '213_2', '217_3', '129_3', '231_3', '149_3', '234_3', '256_3',
#        '255_3', '152_3', '239_3', '228_3', '137_3', '130_3', '103_3',
#        '153_3', '204_3', '155_3', '150_3', '247_3', '221_3', '258_3',
#        '159_3', '124_3', '209_3', '118_3', '105_3', '158_3', '238_3',
#        '227_3', '220_3', '215_3', '156_3', '236_3', '114_3', '136_3',
#        '249_3', '253_3', '115_3', '106_3', '211_3', '113_3', '207_3',
#        '101_3', '230_3', '250_3', '212_3', '216_3', '125_3', '126_3',
#        '134_3', '257_3', '138_3', '154_3', '240_3', '110_3', '208_3',
#        '235_3', '133_3', '254_3', '104_3', '120_3', '224_3', '225_3',
#        '112_3', '223_3', '241_3', '259_3', '107_3', '242_3', '252_3',
#        '151_3', '128_3', '246_3', '102_3', '237_3', '147_3', '210_3',
#        '157_3', '218_3', '243_3', '111_3', '206_3', '251_3', '116_3',
#        '131_3', '142_3', '121_3', '205_3', '132_3', '233_3', '226_3',
#        '140_3', '117_3', '135_3', '127_3', '108_3', '222_3', '122_3',
#        '141_3', '145_3', '245_3', '109_3', '213_3'], dtype=object)

# %%
from hbayesdm.diagnostics import rhat, print_fit, hdi, plot_hdi, extract_ic
from hbayesdm.models import ug_delta, ug_bayes

output1=ug_delta(data=df1,niter=2000,nwarmup=1000,nchain=10,ncore=6)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL ug_delta_ccb98c63d1edecad05e5200ddc3e04ad NOW.
# cc1plus: warning: command line option ‘-Wstrict-prototypes’ is valid for C/ObjC but not for C++
# In file included from /opt/anaconda3/lib/python3.8/site-packages/numpy/core/include/numpy/ndarraytypes.h:1948,
#                  from /opt/anaconda3/lib/python3.8/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/anaconda3/lib/python3.8/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from /tmp/pystan_ft1m2g9l/stanfit4ug_delta_ccb98c63d1edecad05e5200ddc3e04ad_6451472543507137836.cpp:836:
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# In file included from /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/prob/poisson_log_glm_log.hpp:5,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:336,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/src/stan/io/dump.hpp:6,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/py_var_context.hpp:12,
#                  from /tmp/pystan_ft1m2g9l/stanfit4ug_delta_ccb98c63d1edecad05e5200ddc3e04ad_6451472543507137836.cpp:845:
# /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/prob/poisson_log_glm_lpmf.hpp: In function ‘typename stan::return_type<T_x, T_alpha, T_beta>::type stan::math::poisson_log_glm_lpmf(const T_y&, const T_x&, const T_alpha&, const T_beta&)’:
# /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/prob/poisson_log_glm_lpmf.hpp:64:59: warning: typedef ‘T_alpha_val’ locally defined but not used [-Wunused-local-typedefs]
#    64 |       typename partials_return_type<T_alpha>::type>::type T_alpha_val;
#       |                                                           ^~~~~~~~~~~
# In file included from /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/matrix.hpp:19,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/util/ublas_wrapper.hpp:24,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint.hpp:25,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr/functor/integrate_ode_rk45.hpp:17,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr.hpp:46,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:344,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/src/stan/io/dump.hpp:6,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/py_var_context.hpp:12,
#                  from /tmp/pystan_ft1m2g9l/stanfit4ug_delta_ccb98c63d1edecad05e5200ddc3e04ad_6451472543507137836.cpp:845:
# /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/matrix_expression.hpp: In member function ‘void boost::numeric::ublas::matrix_binary<E1, E2, F>::const_iterator1::increment(boost::numeric::ublas::sparse_bidirectional_iterator_tag)’:
# /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/matrix_expression.hpp:2224:17: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#  2224 |                 if (it2_ != it2_end_)
#       |                 ^~
# /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/matrix_expression.hpp:2227:21: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#  2227 |                     if (it2_ != it2_end_) {
#       |                     ^~
# In file included from /tmp/pystan_ft1m2g9l/stanfit4ug_delta_ccb98c63d1edecad05e5200ddc3e04ad_6451472543507137836.cpp:846:
# /opt/anaconda3/lib/python3.8/site-packages/pystan/stan_fit.hpp: In function ‘int pystan::{anonymous}::command(pystan::StanArgs&, Model&, pystan::StanHolder&, const std::vector<long unsigned int>&, const std::vector<std::__cxx11::basic_string<char> >&, RNG_t&)’:
# /opt/anaconda3/lib/python3.8/site-packages/pystan/stan_fit.hpp:841:12: warning: ‘template<class> class std::auto_ptr’ is deprecated [-Wdeprecated-declarations]
#   841 |       std::auto_ptr<stan::io::var_context> init_context_ptr;
#       |            ^~~~~~~~
# In file included from /usr/include/c++/9/memory:80,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/config/no_tr1/memory.hpp:21,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/smart_ptr/shared_ptr.hpp:23,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/shared_ptr.hpp:17,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/LDLT_factor.hpp:7,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/err/check_ldlt_factor.hpp:6,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:34,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/stan/src/stan/io/dump.hpp:6,
#                  from /opt/anaconda3/lib/python3.8/site-packages/pystan/py_var_context.hpp:12,
#                  from /tmp/pystan_ft1m2g9l/stanfit4ug_delta_ccb98c63d1edecad05e5200ddc3e04ad_6451472543507137836.cpp:845:
# /usr/include/c++/9/bits/unique_ptr.h:53:28: note: declared here
#    53 |   template<typename> class auto_ptr;
#       |                            ^~~~~~~~
# In file included from /tmp/pystan_ft1m2g9l/stanfit4ug_delta_ccb98c63d1edecad05e5200ddc3e04ad_6451472543507137836.cpp:848:
# /tmp/pystan_ft1m2g9l/ug_delta_ccb98c63d1edecad05e5200ddc3e04ad.hpp: In member function ‘void ug_delta_ccb98c63d1edecad05e5200ddc3e04ad_namespace::ug_delta_ccb98c63d1edecad05e5200ddc3e04ad::transform_inits(const stan::io::var_context&, std::vector<int>&, std::vector<double>&, std::ostream*) const’:
# /tmp/pystan_ft1m2g9l/ug_delta_ccb98c63d1edecad05e5200ddc3e04ad.hpp:180:24: warning: typedef ‘local_scalar_t__’ locally defined but not used [-Wunused-local-typedefs]
#   180 |         typedef double local_scalar_t__;
#       |                        ^~~~~~~~~~~~~~~~
# /tmp/pystan_ft1m2g9l/stanfit4ug_delta_ccb98c63d1edecad05e5200ddc3e04ad_6451472543507137836.cpp: In function ‘PyObject* __pyx_pf_69stanfit4ug_delta_ccb98c63d1edecad05e5200ddc3e04ad_6451472543507137836_2_call_sampler(PyObject*, PyObject*, PyObject*, PyObject*)’:
# /tmp/pystan_ft1m2g9l/stanfit4ug_delta_ccb98c63d1edecad05e5200ddc3e04ad_6451472543507137836.cpp:9617:30: warning: comparison of integer expressions of different signedness: ‘Py_ssize_t’ {aka ‘long int’} and ‘std::vector<std::__cxx11::basic_string<char> >::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#  9617 |     __pyx_t_12 = ((__pyx_t_9 != __pyx_v_fitptr->param_names_oi().size()) != 0);
#       |                    ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_661451/2798364748.py in <module>
#       2 from hbayesdm.models import ug_delta, ug_bayes
#       3
# ----> 4 output1=ug_delta(data=df1,niter=2000,nwarmup=1000,nchain=10,ncore=6)
#
# /opt/anaconda3/lib/python3.8/site-packages/hbayesdm-1.3.0.9000-py3.8.egg/hbayesdm/models/_ug_delta.py in ug_delta(data, niter, nwarmup, nchain, ncore, nthin, inits, ind_pars, model_regressor, vb, inc_postpred, adapt_delta, stepsize, max_treedepth, **additional_args)
#     218         print_fit(output)
#     219     """
# --> 220     return UgDelta(
#     221         data=data,
#     222         niter=niter,
#
# /opt/anaconda3/lib/python3.8/site-packages/hbayesdm-1.3.0.9000-py3.8.egg/hbayesdm/models/_ug_delta.py in __init__(self, **kwargs)
#      13 class UgDelta(TaskModel):
#      14     def __init__(self, **kwargs):
# ---> 15         super().__init__(
#      16             task_name='ug',
#      17             model_name='delta',
#
# /opt/anaconda3/lib/python3.8/site-packages/hbayesdm-1.3.0.9000-py3.8.egg/hbayesdm/base.py in __init__(self, task_name, model_name, model_type, data_columns, parameters, regressors, postpreds, parameters_desc, additional_args_desc, **kwargs)
#      61         # Run model function
#      62         model, all_ind_pars, par_vals, fit, raw_data, model_regressor \
# ---> 63             = self._run(**kwargs)
#      64
#      65     @property
#
# /opt/anaconda3/lib/python3.8/site-packages/hbayesdm-1.3.0.9000-py3.8.egg/hbayesdm/base.py in _run(self, data, niter, nwarmup, nchain, ncore, nthin, inits, ind_pars, model_regressor, vb, inc_postpred, adapt_delta, stepsize, max_treedepth, **additional_args)
#     158         n_subj = general_info['n_subj']
#     159         if inits == 'vb':
# --> 160             gen_init = self._prepare_gen_init_vb(data_dict, n_subj)
#     161         else:
#     162             gen_init = self._prepare_gen_init(inits, n_subj)
#
# /opt/anaconda3/lib/python3.8/site-packages/hbayesdm-1.3.0.9000-py3.8.egg/hbayesdm/base.py in _prepare_gen_init_vb(self, data_dict, n_subj)
#     441         """
#     442         model = self._get_model_full_name()
# --> 443         sm = self._designate_stan_model(model)
#     444
#     445         try:
#
# /opt/anaconda3/lib/python3.8/site-packages/hbayesdm-1.3.0.9000-py3.8.egg/hbayesdm/base.py in _designate_stan_model(self, model)
#     671             print('Using cached StanModel:', cache_file)
#     672         else:
# --> 673             sm = StanModel(file=model_path, model_name=model,
#     674                            include_paths=[str(PATH_STAN)])
#     675             with open(cache_file, 'wb') as f:
#
# /opt/anaconda3/lib/python3.8/site-packages/pystan/model.py in __init__(self, file, charset, model_name, model_code, stanc_ret, include_paths, boost_lib, eigen_lib, verbose, obfuscate_model_name, extra_compile_args, allow_undefined, include_dirs, includes)
#     376
#     377         try:
# --> 378             build_extension.run()
#     379         finally:
#     380             if redirect_stderr:
#
# /opt/anaconda3/lib/python3.8/site-packages/setuptools/_distutils/command/build_ext.py in run(self)
#     344
#     345         # Now actually compile and link everything.
# --> 346         self.build_extensions()
#     347
#     348     def check_extensions_list(self, extensions):  # noqa: C901
#
# /opt/anaconda3/lib/python3.8/site-packages/setuptools/_distutils/command/build_ext.py in build_extensions(self)
#     464             self._build_extensions_parallel()
#     465         else:
# --> 466             self._build_extensions_serial()
#     467
#     468     def _build_extensions_parallel(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/setuptools/_distutils/command/build_ext.py in _build_extensions_serial(self)
#     490         for ext in self.extensions:
#     491             with self._filter_build_errors(ext):
# --> 492                 self.build_extension(ext)
#     493
#     494     @contextlib.contextmanager
#
# /opt/anaconda3/lib/python3.8/site-packages/setuptools/_distutils/command/build_ext.py in build_extension(self, ext)
#     545             macros.append((undef,))
#     546
# --> 547         objects = self.compiler.compile(
#     548             sources,
#     549             output_dir=self.build_temp,
#
# /opt/anaconda3/lib/python3.8/site-packages/setuptools/_distutils/ccompiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     597             except KeyError:
#     598                 continue
# --> 599             self._compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#     600
#     601         # Return *all* object filenames, not just the ones we just built.
#
# /opt/anaconda3/lib/python3.8/site-packages/setuptools/_distutils/unixccompiler.py in _compile(self, obj, src, ext, cc_args, extra_postargs, pp_opts)
#     184         compiler_so = compiler_fixup(self.compiler_so, cc_args + extra_postargs)
#     185         try:
# --> 186             self.spawn(compiler_so + cc_args + [src, '-o', obj] + extra_postargs)
#     187         except DistutilsExecError as msg:
#     188             raise CompileError(msg)
#
# /opt/anaconda3/lib/python3.8/site-packages/setuptools/_distutils/ccompiler.py in spawn(self, cmd, **kwargs)
#    1005
#    1006     def spawn(self, cmd, **kwargs):
# -> 1007         spawn(cmd, dry_run=self.dry_run, **kwargs)
#    1008
#    1009     def move_file(self, src, dst):
#
# /opt/anaconda3/lib/python3.8/site-packages/setuptools/_distutils/spawn.py in spawn(cmd, search_path, verbose, dry_run, env)
#      56     try:
#      57         proc = subprocess.Popen(cmd, env=env)
# ---> 58         proc.wait()
#      59         exitcode = proc.returncode
#      60     except OSError as exc:
#
# /opt/anaconda3/lib/python3.8/subprocess.py in wait(self, timeout)
#    1081             endtime = _time() + timeout
#    1082         try:
# -> 1083             return self._wait(timeout=timeout)
#    1084         except KeyboardInterrupt:
#    1085             # https://bugs.python.org/issue25942
#
# /opt/anaconda3/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1804                         if self.returncode is not None:
#    1805                             break  # Another thread waited.
# -> 1806                         (pid, sts) = self._try_wait(0)
#    1807                         # Check the pid and loop as waitpid has been known to
#    1808                         # return 0 even without WNOHANG in odd situations.
#
# /opt/anaconda3/lib/python3.8/subprocess.py in _try_wait(self, wait_flags)
#    1762             """All callers to this function MUST hold self._waitpid_lock."""
#    1763             try:
# -> 1764                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1765             except ChildProcessError:
#    1766                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
output2=ug_delta(data=df2,niter=2000,nwarmup=1000,nchain=10,ncore=6)

# %%
output3=ug_delta(data=df3,niter=2000,nwarmup=1000,nchain=10,ncore=6)

# %%
output4=ug_delta(data=df4,niter=2000,nwarmup=1000,nchain=10,ncore=6)

# %% [markdown]
# # Partner 1
# - Over all looks good.
# - Rhat all 1.01 or less
# - Traces all converge more or less, no drift, though an occasional but expected extreme value.
# - Additional note that about 2.5% of the mu_alpha posterior is greater than 1

# %%
import numpy as np
np.sum(output1.par_vals['mu_alpha']>1)/len(output1.par_vals['mu_alpha'])

# %%
import matplotlib.pyplot as plt
output1.plot('trace')
plt.show()
display(output1.fit)

# %% [markdown]
# # Partner 2
# - Rhat for mu_aplha is 1.02 suggesting some notable non-convergence.
# - This can be seen a little in the chain

# %%
output2.plot('trace')
plt.show()
display(output2.fit)

# %% [markdown]
# # Partner 3
# - Rhat below or at 1.01

# %%
output3.plot('trace')
plt.show()
display(output3.fit)

# %% [markdown]
# # Output4

# %% [markdown]
# # Maybe worry about later
# - Many individuals have wide posteriors for alpha and tau
# - A wide posterior indicates large uncertainty in their individual estimates

# %%
output1.plot_ind()

# %% [markdown]
# # Condition effects on parameters
# - Generally no effect of condition on learning rate overall
# ## Partner 1 vs 2

# %%
for val in output1.par_vals:
    if val.startswith('mu_'):
        alpha_diff12=output1.par_vals[val]-output2.par_vals[val]
        display(hdi(alpha_diff12))  # Compute the 95% Highest Density Interval (HDI).
        #plot_hdi( alpha_diff12 )    # plot the group mean differences

# %% [markdown]
# ## Partner 1 vs 3

# %%
for val in output1.par_vals:
    if val.startswith('mu_'):
        alpha_diff12=output1.par_vals[val]-output3.par_vals[val]
        display(hdi(alpha_diff12))  # Compute the 95% Highest Density Interval (HDI).
        #plot_hdi( alpha_diff12 )    # plot the group mean differences

# %% [markdown]
# ## Partner 2 vs 3

# %%
for val in output1.par_vals:
    if val.startswith('mu_'):
        alpha_diff12=output2.par_vals[val]-output3.par_vals[val]
        display(hdi(alpha_diff12))  # Compute the 95% Highest Density Interval (HDI).
        #plot_hdi( alpha_diff12 )    # plot the group mean differences

# %%
res_df1=[]
res_df1=output1.all_ind_pars.reset_index().rename(columns={'index':'participant_id'})
res_df1['participant_id']='sub-'+res_df1['participant_id']

res_df2=[]
res_df2=output2.all_ind_pars.reset_index().rename(columns={'index':'participant_id'})
res_df2['participant_id']='sub-'+res_df2['participant_id']

res_df3=[]
res_df3=output3.all_ind_pars.reset_index().rename(columns={'index':'participant_id'})
res_df3['participant_id']='sub-'+res_df3['participant_id']

res_df=res_df1.merge(res_df2,on='participant_id',suffixes=('_1','_2'))
res_df=res_df.merge(res_df3,on='participant_id',suffixes=('_3'))

# %%
ages=pd.read_csv('../../srndna-data/bids/participants.tsv',sep='\t')
display(res_df.head())
display(ages.head())

# %%
res_df=res_df.merge(ages,on='participant_id')
display(res_df.head())
res_df['ep_diff']=res_df['ep_1']-res_df['ep_2']
res_df.to_csv('../derivatives/delat_values.csv',index=False)

# %%
import seaborn as sms
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols
import numpy as np
#from statsmodels.api.stats import anoval_lm
res_df['Old']=res_df['age']>50
for item in res_df.columns:
    if any(x in item for x in ['alpha','tau','ep']): 
        plt_df=res_df.copy()
        #plt_df[item]=np.sqrt(plt_df[item])
        #plt_df=plt_df[plt_df[item]<=2.5]
        res=ols('%s~Old'%(item),data=plt_df).fit()
        display(res.summary())
        #sms.catplot(x='Old',y=item,data=plt_df,kind='bar',dodge=True,hue='sex',ci=68)
        sms.catplot(x='Old',y=item,data=plt_df,kind='bar',dodge=True,ci=68)
        plt.show()

# %%
P1_df=df[df['Partner']==1]
P2_df=df[df['Partner']==2]
P3_df=df[df['Partner']==3]


P1res=ug_delta(data=P1_df,niter=2000,nwarmup=1000,nchain=10,ncore=10)
P2res=ug_delta(data=P2_df,niter=2000,nwarmup=1000,nchain=10,ncore=10)
P3res=ug_delta(data=P3_df,niter=2000,nwarmup=1000,nchain=10,ncore=10)

# %%
P1res.plot('trace')
P2res.plot('trace')
P3res.plot('trace')
